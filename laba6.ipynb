# %% [markdown]
# # Лабораторная работа 6. Линейная регрессия

# %% [markdown]
# ## <a href="https://www.kaggle.com/datasets/canggih/anime-data-score-staff-synopsis-and-genre">Anime Data с сайта MyAnimeList.net</a>

# %% [markdown]
# ### Описание набора данных:
# Японская анимация, известная как аниме, в наши дни получила международное распространение. В этом наборе данных представлены данные об аниме, взятые из MyAnimeList.

# %% [markdown]
# ### Прилогающаяся информация:
# Этот набор данных можно использовать для создания систем рекомендаций, прогнозирования результатов, визуализации сходства с аниме и т.д.

# %% [markdown]
# 1) Title - Название - Categorical
# 2) Type - Тип аниме - Categorical TV/Movie/OVA/ONA/Special
# 3) Episodes - Количество эпизодов - Integer
# 4) Status - Статус - Categorical 'Finished Airing' | 'Currently Airing'
# 5) Start airing - Начало показа - Categorical 'YYYY-M-D'
# 6) End airing - Конец показа - Categorical 'YYYY-M-D'
# 7) Starting season - Время года показа - Categorical 'Fall' | 'Summer' | 'Winter' | 'Spring'
# 8) Broadcast time - Время трансляции - Categorical 'Day of the week' at 'HH:MM' (JST)
# 9) Producers - Продюссер - Categorical
# 10) Licensors - Лицензия - Categorical
# 11) Studios - Студия - Categorical
# 12) Sources - Первоисточник - Categorical 'Manga' | 'Original' | 'Light novel' | 'Novel'
# 13) Genres - Жанр - Categorical
# 14) Duration - Продолжительность - Categorical
# 15) Rating - Categorical 'G' | 'PG-13' | 'PG' | 'R'
# 16) Score - Средняя оценка - Continuous
# 17) Scored by - Количество оценок - Integer
# 18) Members - Подписчики - Integer
# 19) Favorites - В избранном - Integer
# 20) Description - Описание - Categorical

# %% [markdown]
# Подключение библиотек

# %%
from __future__ import division, print_function
import numpy as np
import pandas as pd
import scipy
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# Чтение исходного набора данных

# %%
ds_anime = pd.read_csv('dataanime.csv')
test_anime = pd.read_csv('dataanime.csv', nrows=10)
print(ds_anime)
print('///////////////////////////////////////////////////////////////////')
print(test_anime)
# Out:
#                                                   Title     Type Episodes  \
# 0                      Fullmetal Alchemist: Brotherhood       TV       64
# 1                                        Kimi no Na wa.    Movie        1
# 2                                              Gintama°       TV       51
# 3                                         Steins;Gate 0       TV       23
# 4                                           Steins;Gate       TV       24
# 5                                  Ginga Eiyuu Densetsu      OVA      110
# 6                                              Gintama'       TV       51
# 7                                Hunter x Hunter (2011)       TV      148
# 8                            3-gatsu no Lion 2nd Season       TV       22
# 9                                   Gintama': Enchousen       TV       13
# 10    Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...    Movie        1
# 11                                       Koe no Katachi    Movie        1
# 12                           Owarimonogatari 2nd Season       TV        7
# 13                                             Gintama.       TV       12
# 14                                 Clannad: After Story       TV       24
# 15                                              Gintama       TV      201
# 16    Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...       TV       10
# 17                   Code Geass: Hangyaku no Lelouch R2       TV       25
# 18                                        Made in Abyss       TV       13
# 19                        Sen to Chihiro no Kamikakushi    Movie        1
# 20                              Haikyuu!! Second Season       TV       25
# 21                     Kizumonogatari III: Reiketsu-hen    Movie        1
# 22                              Shigatsu wa Kimi no Uso       TV       22
# 23                  Gintama.: Shirogane no Tamashii-hen       TV       12
# 24    Shouwa Genroku Rakugo Shinjuu: Sukeroku Futata
# 26       Saturdays at 01:00 (JST)
# 27        Tuesdays at 00:50 (JST)
# 28                              -
# 29         Fridays at 01:25 (JST)
# ...                           ...
# 1533                            -
# 1534                            -
# 1535                            -
# 1536                            -
# 1537                            -
# 1538                            -
# 1539                            -
# 1540     Saturdays at 03:10 (JST)
# 1541                            -
# 1542                            -
# 1543                            -
# 1544                            -
# 1545       Sundays at 01:00 (JST)
# 1546       Fridays at 00:45 (JST)
# 1547                            -
# 1548                            -
# 1549                            -
# 1550                            -
# 1551                            -
# 1552                            -
# 1553       Sundays at 01:30 (JST)
# 1554                            -
# 1555                            -
# 1556       Fridays at 01:25 (JST)
# 1557      Tuesdays at 18:30 (JST)
# 1558                            -
# 1559                            -
# 1560                            -
# 1561                            -
# 1562      Tuesdays at 02:05 (JST)
#
#                                               Producers  \
# 0     Aniplex,Square Enix,Mainichi Broadcasting Syst...
# 1     Kadokawa Shoten,Toho,Sound Team Don Juan,Lawso...
# 2                               TV Tokyo,Aniplex,Dentsu
# 3                                             Nitroplus
# 4     Frontier Works,Media Factory,Movic,AT-X,Kadoka...
# 5                                           Kitty Films
# 6     TV Tokyo,Aniplex,Dentsu,Trinity Sound,Miracle ...
# 7                VAP,Nippon Television Network,Shueisha
# 8     Aniplex,Dentsu,NHK,Hakusensha,Asmik Ace Entert...
# 9          TV Tokyo,Aniplex,Dentsu,Shueisha,Miracle Bus
# 10    TV Tokyo,Aniplex,Dentsu,Bandai,Warner Bros.,Sh...
# 11    Shochiku,Pony Canyon,Kodansha,ABC Animation,Qu...
# 12                                     Aniplex,Kodansha
# 13                     TV Tokyo,Aniplex,Dentsu,Shueisha
# 14               Pony Canyon,TBS,Rakuonsha,Animation Do
# 15    TV Tokyo,Aniplex,Dentsu,Trinity Sound,Audio Hi...
# 16                              TOHO animation,Shueisha
# 17    Bandai Visual,Mainichi Broadcasting System,Ban...
# 18    Media Factory,AT-X,Takeshobo,Sony Music Commun...
# 19                                                 Toho
# 20                              TOHO animation,Shueisha
# 21                                     Aniplex,Kodansha
# 22    Aniplex,Dentsu,Kodansha,Fuji TV,Kyoraku Indust...
# 23                     TV Tokyo,Aniplex,Dentsu,Shueisha
# 24    Mainichi Broadcasting System,Kodansha,DAX Prod...
# 25                         Aniplex,Kodansha,Delfi Sound
# 26                                        Bandai Visual
# 27                                                  VAP
# 28              Tokuma Shoten,Nippon Television Network
# 29    Bandai Visual,Mainichi Broadcasting System,Ban...
# ...                                                 ...
# 1533                                                  -
# 1534                                                  -
# 1535                    Starchild Records,Omnibus Japan
# 1536                                  Starchild Records
# 1537                                          WAO World
# 1538      Pony Canyon,TBS,Kodansha,Movic,DAX Production
# 1539                                                  -
# 1540  Starchild Records,Memory-Tech,Bushiroad,MAGES....
# 1541                                                  -
# 1542                                     Jade Animation
# 1543                                                  -
# 1544  Bandai Visual,Lantis,Movic,Showgate,Hakuhodo D...
# 1545                               Bandai Visual,Lantis
# 1546  Dentsu,Fuji TV,Toho,Sony Music Entertainment,F...
# 23             Bandai Namco Pictures         Manga
# 24                       Studio Deen         Manga
# 25                           Artland         Manga
# 26                           Sunrise      Original
# 27                          Madhouse         Manga
# 28                     Studio Ghibli      Original
# 29                           Sunrise      Original
# ...                              ...           ...
# 1533                       J.C.Staff         Manga
# 1534                               -             -
# 1535                      Seven Arcs      Original
# 1536                           feel.         Manga
# 1537                               -             -
# 1538                           feel.   Light novel
# 1539                               -             -
# 1540                       Satelight      Original
# 1541                 Studio Colorido             -
# 1542                Nippon Animation         Novel
# 1543                  TYO Animations      Original
# 1544                           Bones      Original
# 1545                      P.A. Works      Original
# 1546                           Bones         Novel
# 1547  Studio Comet,KeyEast,REALTHING         Other
# 1548                               -         Novel
# 1549                    Science SARU      Original
# 1550     Studio Pierrot,Pierrot Plus      Original
# 1551                         Sunrise             -
# 1552                               -         Manga
# 1553                         Sunrise      Original
# 1554                        ufotable  Visual novel
# 1555                Nippon Animation         Other
# 1556                           Shaft  4-koma manga
# 1557               TMS Entertainment         Manga
# 1558                    A-1 Pictures         Manga
# 1559                           feel.         Manga
# 1560                  Studio Pierrot         Manga
# 1561                    AIC A.S.T.A.             -
# 1562                          Lerche      Original
#
#                                                  Genres         Duration  \
# 0     Action,Military,Adventure,Comedy,Drama,Magic,F...  24 min. per ep.
# 1                     Supernatural,Drama,Romance,School    1 hr. 46 min.
# 2     Action,Comedy,Historical,Parody,Samurai,Sci-Fi...  24 min. per ep.
# 3                                       Sci-Fi,Thriller  23 min. per ep.
# 4                                       Sci-Fi,Thriller  24 min. per ep.
# 5                           Military,Sci-Fi,Space,Drama  26 min. per ep.
# 6     Action,Sci-Fi,Comedy,Historical,Parody,Samurai...  24 min. per ep.
# 7                  Action,Adventure,Super Power,Shounen  23 min. per ep.
# 8                       Drama,Game,Seinen,Slice of Life  25 min. per ep.
# 9     Action,Comedy,Historical,Parody,Samurai,Sci-Fi...  24 min. per ep.
# 10    Action,Sci-Fi,Comedy,Historical,Parody,Samurai...    1 hr. 50 min.
# 11                                 Drama,School,Shounen    2 hr. 10 min.
# 12                  Mystery,Comedy,Supernatural,Vampire  22 min. per ep.
# 13    Action,Comedy,Historical,Parody,Samurai,Sci-Fi...  24 min. per ep.
# 14      Slice of Life,Comedy,Supernatural,Drama,Romance  24 min. per ep.
# 15    Action,Sci-Fi,Comedy,Historical,Parody,Samurai...  24 min. per ep.
# 16                   Comedy,Sports,Drama,School,Shounen  24 min. per ep.
# 17       Action,Drama,Mecha,Military,Sci-Fi,Super Power  24 min. per ep.
# 18               Sci-Fi,Adventure,Mystery,Drama,Fantasy  25 min. per ep.
# 19                         Adventure,Supernatural,Drama     2 hr. 5 min.
# 20                   Comedy,Sports,Drama,School,Shounen  24 min. per ep.
# 21                  Action,Mystery,Supernatural,Vampire    1 hr. 23 min.
# 22                   Drama,Music,Romance,School,Shounen  22 min. per ep.
# 23    Action,Sci-Fi,Comedy,Historical,Parody,Samurai...  24 min. per ep.
# 24                               Historical,Drama,Josei  24 min. per ep.
# 25    Adventure,Fantasy,Historical,Mystery,Seinen,Sl...  23 min. per ep.
# 26           Action,Adventure,Comedy,Drama,Sci-Fi,Space  24 min. per ep.
# 27                          Comedy,Sports,Drama,Shounen  23 min. per ep.
# 28                             Action,Adventure,Fantasy    2 hr. 10 min.
# 29    Action,Military,Sci-Fi,Super Power,Drama,Mecha...  24 min. per ep.
# ...                                                 ...              ...
# 1533                               Slice of Life,Comedy          23 min.
# 1534                         Music,School,Slice of Life          30 min.
# 1535              Action,Comedy,Drama,Magic,Super Power  25 min. per ep.
# 1536                               Comedy,Slice of Life          25 min.
# 1537                                   Historical,Music    1 hr. 39 min.
# 1538                        Harem,Comedy,Parody,Fantasy  24 min. per ep.
# 1539                                          Adventure    2 hr. 15 min.
# 1540                                Action,Music,Sci-Fi  23 min. per ep.
# 1541                     Drama,Historical,Slice of Life          16 min.
# 1542                 Adventure,Drama,Historical,Romance  24 min. per ep.
# 1543                         Comedy,Drama,Slice of Life          24 min.
# 1544                    Action,Super Power,Supernatural          48 min.
# 1545                               Drama,Romance,School  24 min. per ep.
# 1546                               Mystery,Supernatural  24 min. per ep.
# 1547                                      Drama,Romance  25 min. per ep.
# 1548  Action,Adventure,Fantasy,Martial Arts,Romance,...   8 min. per ep.
# 1549                            Adventure,Music,Fantasy    1 hr. 57 min.
# 1550   Action,Comedy,Supernatural,Demons,School,Shounen   2 min. per ep.
# 1551                      Action,Comedy,Mystery,Shounen          45 min.
# 1552            Historical,Drama,Romance,Samurai,Seinen    1 hr. 33 min.
# 1553                                Action,Sci-Fi,Mecha  23 min. per ep.
# 1554                  Action,Supernatural,Magic,Fantasy           9 min.
# 1555                Adventure,Comedy,Fantasy,Kids,Magic  20 min. per ep.
# 1556                 Slice of Life,Comedy,School,Seinen  24 min. per ep.
# 1557                    Mystery,Horror,Thriller,Shounen  25 min. per ep.
# 1558  Action,Comedy,Demons,Supernatural,Fantasy,Shounen  24 min. per ep.
# 1559                               Comedy,Slice of Life          28 min.
# 1560     Action,Comedy,Martial Arts,Shounen,Super Power    1 hr. 35 min.
# 1561  Adventure,Mystery,Super Power,Supernatural,School    1 hr. 30 min.
# 1562                   Mystery,Comedy,Super Power,Drama  24 min. per ep.
#
#      Rating  Score  Scored by  Members  Favorites  \
# 0         R   9.25     719706  1176368     105387
# 1     PG-13   9.19     454969   705186      33936
# 2         R   9.16      70279   194359       5597
# 3     PG-13   9.16      12609   186331       1117
# 4     PG-13   9.14     552791   990419      90365
# 5         R   9.11      28452   121772       8370
# 6     PG-13   9.11      90758   212238       4533
# 7     PG-13   9.11     395162   705225      63324
# 8     PG-13   9.10      26284    80166       1961
# 9     PG-13   9.07      62582   121612       1498
# 10    PG-13   9.04      60295   104021       1374
# 11    PG-13   9.04     283214   491799      18911
# 12        R   9.03      40936   109651       2372
# 13    PG-13   9.02      39493    89409       1222
# 14    PG-13   9.01     359297   599866      47076
# 15    PG-13   9.01     139984   452486      33507
# 16    PG-13   8.99     154220   245797       4078
# 17        R   8.95     536915   780346      43856
# 9    2012-10-4  2013-3-28            Fall   Thursdays at 18:00 (JST)
#
#                                            Producers  \
# 0  Aniplex,Square Enix,Mainichi Broadcasting Syst...
# 1  Kadokawa Shoten,Toho,Sound Team Don Juan,Lawso...
# 2                            TV Tokyo,Aniplex,Dentsu
# 3                                          Nitroplus
# 4  Frontier Works,Media Factory,Movic,AT-X,Kadoka...
# 5                                        Kitty Films
# 6  TV Tokyo,Aniplex,Dentsu,Trinity Sound,Miracle ...
# 7             VAP,Nippon Television Network,Shueisha
# 8  Aniplex,Dentsu,NHK,Hakusensha,Asmik Ace Entert...
# 9       TV Tokyo,Aniplex,Dentsu,Shueisha,Miracle Bus
#
#                        Licensors                Studios       Sources  \
# 0  Funimation,Aniplex of America                  Bones         Manga
# 1           Funimation,NYAV Post       CoMix Wave Films      Original
# 2         Funimation,Crunchyroll  Bandai Namco Pictures         Manga
# 3                     Funimation              White Fox  Visual novel
# 4                     Funimation              White Fox  Visual novel
# 5               Sentai Filmworks      Artland,Magic Bus         Novel
# 6                              -                Sunrise         Manga
# 7                      Viz Media               Madhouse         Manga
# 8             Aniplex of America                  Shaft         Manga
# 9                              -                Sunrise         Manga
#
#                                               Genres         Duration Rating  \
# 0  Action,Military,Adventure,Comedy,Drama,Magic,F...  24 min. per ep.      R
# 1                  Supernatural,Drama,Romance,School    1 hr. 46 min.  PG-13
# 2  Action,Comedy,Historical,Parody,Samurai,Sci-Fi...  24 min. per ep.      R
# 3                                    Sci-Fi,Thriller  23 min. per ep.  PG-13
# 4                                    Sci-Fi,Thriller  24 min. per ep.  PG-13
# 5                        Military,Sci-Fi,Space,Drama  26 min. per ep.      R
# 6  Action,Sci-Fi,Comedy,Historical,Parody,Samurai...  24 min. per ep.  PG-13
# 7               Action,Adventure,Super Power,Shounen  23 min. per ep.  PG-13
# 8                    Drama,Game,Seinen,Slice of Life  25 min. per ep.  PG-13
# 9  Action,Comedy,Historical,Parody,Samurai,Sci-Fi...  24 min. per ep.  PG-13
#
#    Score  Scored by  Members  Favorites  \
# 0   9.25     719706  1176368     105387
# 1   9.19     454969   705186      33936
# 2   9.16      70279   194359       5597
# 3   9.16      12609   186331       1117
# 4   9.14     552791   990419      90365
# 5   9.11      28452   121772       8370
# 6   9.11      90758   212238       4533
# 7   9.11     395162   705225      63324
# 8   9.10      26284    80166       1961
# 9   9.07      62582   121612       1498
#
#                                          Description
# 0  "In order for something to be obtained, someth...
# 1  Mitsuha Miyamizu, a high school girl, yearns t...
# 2  Gintoki, Shinpachi, and Kagura return as the f...
# 3  The dark untold story of Steins;Gate that lead...
# 4  The self-proclaimed mad scientist Rintarou Oka...
# 5  The 150-year-long stalemate between the two in...
# 6  After a one-year hiatus, Shinpachi Shimura ret...
# 7  Hunter x Hunter is set in a world where Hunter...
# 8  Now in his second year of high school, Rei Kir...
# 9  While Gintoki Sakata was away, the Yorozuya fo...

# %%
print(ds_anime.head(1).T)
print('/////////////////////////////////////////////////////////////////////////')
print(test_anime.head(1).T)
# Out:
#                                                                  0
# Title                             Fullmetal Alchemist: Brotherhood
# Type                                                            TV
# Episodes                                                        64
# Status                                             Finished Airing
# Start airing                                              2009-4-5
# End airing                                                2010-7-4
# Starting season                                             Spring
# Broadcast time                              Sundays at 17:00 (JST)
# Producers        Aniplex,Square Enix,Mainichi Broadcasting Syst...
# Licensors                            Funimation,Aniplex of America
# Studios                                                      Bones
# Sources                                                      Manga
# Genres           Action,Military,Adventure,Comedy,Drama,Magic,F...
# Duration                                           24 min. per ep.
# Rating                                                           R
# Score                                                         9.25
# Scored by                                                   719706
# Members                                                    1176368
# Favorites                                                   105387
# Description      "In order for something to be obtained, someth...
# /////////////////////////////////////////////////////////////////////////
#                                                                  0
# Title                             Fullmetal Alchemist: Brotherhood
# Type                                                            TV
# Episodes                                                        64
# Status                                             Finished Airing
# Start airing                                              2009-4-5
# End airing                                                2010-7-4
# Starting season                                             Spring
# Broadcast time                              Sundays at 17:00 (JST)
# Producers        Aniplex,Square Enix,Mainichi Broadcasting Syst...
# Licensors                            Funimation,Aniplex of America
# Studios                                                      Bones
# Sources                                                      Manga
# Genres           Action,Military,Adventure,Comedy,Drama,Magic,F...
# Duration                                           24 min. per ep.
# Rating                                                           R
# Score                                                         9.25
# Scored by                                                   719706
# Members                                                    1176368
# Favorites                                                   105387
# Description      "In order for something to be obtained, someth...

# %% [markdown]
# Тестовый набор состоит из первый десяти элементов.

# %%
print('Обучающая выборка: \t', ds_anime.shape)
print('Тестовый набор: \t', test_anime.shape)
# Out:
# Обучающая выборка: 	 (1563, 20)
# Тестовый набор: 	 (10, 20)

# %%
print(ds_anime.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1563 entries, 0 to 1562
# Data columns (total 20 columns):
# Title              1563 non-null object
# Type               1563 non-null object
# Episodes           1563 non-null object
# Status             1563 non-null object
# Start airing       1563 non-null object
# End airing         1563 non-null object
# Starting season    1563 non-null object
# Broadcast time     1563 non-null object
# Producers          1563 non-null object
# Licensors          1563 non-null object
# Studios            1563 non-null object
# Sources            1563 non-null object
# Genres             1563 non-null object
# Duration           1563 non-null object
# Rating             1563 non-null object
# Score              1563 non-null float64
# Scored by          1563 non-null int64
# Members            1563 non-null int64
# Favorites          1563 non-null int64
# Description        1563 non-null object
# dtypes: float64(1), int64(3), object(16)
# memory usage: 244.3+ KB
# None

# %% [markdown]
# Корреляция признаков

# %%
corr = ds_anime.corr()
corr[corr>0.9].replace({np.nan : ''})
# Out:
#               Score  Scored by   Members  Favorites
# Score      1.000000   0.391728  0.414776   0.410764
# Scored by  0.391728   1.000000  0.985944   0.825586
# Members    0.414776   0.985944  1.000000   0.820924
# Favorites  0.410764   0.825586  0.820924   1.000000

# %% [markdown]
# Количество аниме выпущенное за различные года

# %%
df = ds_anime.copy()
df['Start airing'] = pd.to_datetime(df['Start airing']).dt.year
ss = df['Start airing'].value_counts()
print(ss.sort_index())
# Out:
# 1970.0      1
# 1971.0      1
# 1974.0      1
# 1975.0      1
# 1976.0      1
# 1977.0      2
# 1978.0      6
# 1979.0      6
# 1980.0      2
# 1981.0      4
# 1982.0      8
# 1983.0      4
# 1984.0      5
# 1985.0      6
# 1986.0      5
# 1987.0      6
# 1988.0     11
# 1989.0      9
# 1990.0      9
# 1991.0      8
# 1992.0     10
# 1993.0     12
# 1994.0     14
# 1995.0     20
# 1996.0     18
# 1997.0     12
# 1998.0     14
# 1999.0     24
# 2000.0     16
# 2001.0     19
# 2002.0     28
# 2003.0     31
# 2004.0     39
# 2005.0     51
# 2006.0     57
# 2007.0     72
# 2008.0     75
# 2009.0     84
# 2010.0     81
# 2011.0     95
# 2012.0     89
# 2013.0     94
# 2014.0    114
# 2015.0    113
# 2016.0    115
# 2017.0    110
# 2018.0     46
# Name: Start airing, dtype: int64

# %% [markdown]
# Работа с TfidfVectorizer

# %%
# Определение списка признаков для обучения модели
feats = ['Title', 'Licensors', 'Studios', 'Sources']

# Вычисление размера обучающей подвыборки (70% от размера исходного набора данных)
train_size = int(0.7 * ds_anime.shape[0])

# Вывод информации о размере исходного набора данных и размере обучающей подвыборки
print('Размер исходного набора: ', len(ds_anime), \
      '\nРазмер обучающей подвыборки: ', train_size)

# Выделение признаков и целевой переменной для обучающей и тестовой выборок
X, y = ds_anime.loc[:, feats], ds_anime['Score']
X_test = test_anime.loc[:, feats]
X_train, X_valid = X.iloc[:train_size, :], X.iloc[train_size:, :]
y_train, y_valid = y.iloc[:train_size], y.iloc[train_size:]
# Out:
# Размер исходного набора:  1563
# Размер обучающей подвыборки:  1094

# %% [markdown]
# Создадим три словаря и три матрицы TF-IDF — <i>статистическая мера, используемая для оценки важности слова в контексте документа, являющегося частью коллекции документов или корпуса</i>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Инициализация TfidfVectorizer с заданными параметрами
vectorizer_title = TfidfVectorizer(min_df=3, max_df=0.3, ngram_range=(1,3))

# Обучение TfidfVectorizer на обучающих данных и вывод размера словаря
vX_train_title = vectorizer_title.fit(X_train['Title'])
print('vX_train_title.vocabulary_: ', len(vX_train_title.vocabulary_))

# Применение обученного TfidfVectorizer к валидационным данным и вывод размера словаря
vX_valid_title = vectorizer_title.fit(X_valid['Title'])
print('vX_train_title.vocabulary_: ', len(vX_valid_title.vocabulary_))

# Применение обученного TfidfVectorizer к тестовым данным и вывод размера словаря
vX_test_title = vectorizer_title.fit(X_test['Title'])
print('vX_train_title.vocabulary_: ', len(vX_test_title.vocabulary_))

# Преобразование обучающих данных с помощью обученного TfidfVectorizer и вывод размера полученной матрицы
X_train_title = vectorizer_title.fit_transform(X_train['Title'])
print('X_train_title.shape: ', X_train_title.shape)

# Преобразование валидационных данных с помощью обученного TfidfVectorizer и вывод размера полученной матрицы
X_valid_title = vectorizer_title.transform(X_valid['Title'])
print('X_valid_title.shape: ', X_valid_title.shape)

# Преобразование тестовых данных с помощью обученного TfidfVectorizer и вывод размера полученной матрицы
X_test_title = vectorizer_title.transform(X_test['Title'])
print('X_test_title.shape: ', X_test_title.shape)
# Out:
# vX_train_title.vocabulary_:  726
# vX_train_title.vocabulary_:  235
# vX_train_title.vocabulary_:  1
# X_train_title.shape:  (1094, 726)
# X_valid_title.shape:  (469, 726)
# X_test_title.shape:  (10, 726)

# %% [markdown]
# Вывод полей тестовой матрицы TF-IDF

# %%
vX_test_title.vocabulary_
# Out:
# {'fullmetal': 134,
#  'alchemist': 16,
#  'fullmetal alchemist': 135,
#  'kimi': 270,
#  'no': 399,
#  'na': 374,
#  'wa': 667,
#  'kimi no': 271,
#  'gintama': 157,
#  'steins': 599,
#  'gate': 142,
#  'steins gate': 600,
#  'ginga': 154,
#  'eiyuu': 112,
#  'densetsu': 94,
#  'ginga eiyuu': 155,
#  'eiyuu densetsu': 113,
#  'ginga eiyuu densetsu': 156,
#  'hunter': 208,
#  'hunter hunter': 209,
#  '2nd': 4,
#  'season': 522,
#  '2nd season': 5,
#  'movie': 362,
#  'kanketsu': 257,
#  'hen': 187,
#  'yo': 694,
#  'eien': 111,
#  'kanketsu hen': 258,
#  'clannad': 74,
#  'story': 601,
#  'haikyuu': 169,
#  'koukou': 288,
#  'vs': 666,
#  'gakuen': 139,
#  'code': 76,
#  'geass': 143,
#  'hangyaku': 178,
#  'lelouch': 307,
#  'code geass': 77,
#  'geass hangyaku': 144,
#  'hangyaku no': 179,
#  'no lelouch': 418,
#  'code geass hangyaku': 78,
#  'geass hangyaku no': 145,
#  'hangyaku no lelouch': 180,
#  'in': 220,
#  'to': 644,
#  'second': 523,
#  'second season': 524,
#  'iii': 219,
#  'shouwa': 574,
#  'genroku': 146,
#  'rakugo': 490,
#  'shinjuu': 561,
#  'shouwa genroku': 575,
#  'genroku rakugo': 147,
#  'rakugo shinjuu': 491,
#  'shouwa genroku rakugo': 576,
#  'genroku rakugo shinjuu': 148,
#  'mushishi': 371,
#  'zoku': 724,
#  'shou': 568,
#  'mushishi zoku': 372,
#  'zoku shou': 725,
#  'mushishi zoku shou': 373,
#  'hajime': 171,
#  'ippo': 227,
#  'hajime no': 172,
#  'no ippo': 407,
#  'hajime no ippo': 173,
#  'hime': 198,
#  'rurouni': 500,
#  'kenshin': 265,
#  'meiji': 344,
#  'kenkaku': 263,
#  'romantan': 497,
#  'rurouni kenshin': 501,
#  'kenshin meiji': 266,
#  'meiji kenkaku': 345,
#  'kenkaku romantan': 264,
#  'rurouni kenshin meiji': 502,
#  'kenshin meiji kenkaku': 267,
#  'meiji kenkaku romantan': 346,
#  'boku': 53,
#  'hero': 189,
#  'academia': 9,
#  'boku no': 54,
#  'no hero': 405,
#  'hero academia': 190,
#  'boku no hero': 55,
#  'no hero academia': 406,
#  'monogatari': 359,
#  'series': 550,
#  'ookami': 459,
#  'kodomo': 281,
#  'natsume': 384,
#  'yuujinchou': 703,
#  'natsume yuujinchou': 385,
#  'new': 386,
#  'shiro': 565,
#  'one': 453,
#  'punch': 488,
#  'man': 338,
#  'one punch': 457,
#  'punch man': 489,
#  'one punch man': 458,
#  'shi': 556,
#  'ii': 218,
#  'bakuman': 35,
#  '3rd': 7,
#  '3rd season': 8,
#  'death': 93,
#  'nan': 380,
#  'tv': 658,
#  'ansatsu': 23,
#  'kyoushitsu': 304,
#  'ansatsu kyoushitsu': 24,
#  'fate': 123,
#  'zero': 718,
#  'the': 632,
#  'city': 72,
#  'in the': 221,
#  'san': 516,
#  'animation': 19,
#  'the animation': 633,
#  'yori': 695,
#  'mo': 355,
#  'basho': 37,
#  'shinwa': 562,
#  'jojo': 236,
#  'kimyou': 272,
#  'bouken': 59,
#  'diamond': 100,
#  'jojo no': 237,
#  'no kimyou': 411,
#  'kimyou na': 273,
#  'na bouken': 375,
#  'jojo no kimyou': 238,
#  'no kimyou na': 412,
#  'kimyou na bouken': 274,
#  'special': 588,
#  'go': 159,
#  'kara': 260,
#  'kyoukai': 301,
#  'kara no': 261,
#  'no kyoukai': 417,
#  'kara no kyoukai': 262,
#  'ashita': 31,
#  'aria': 28,
#  'aria the': 29,
#  'ga': 136,
#  'uchuu': 659,
#  'kyoudai': 300,
#  'ano': 20,
#  'hi': 192,
#  'hana': 176,
#  'wo': 678,
#  'ano hi': 21,
#  'hana no': 177,
#  'ghost': 150,
#  'shell': 553,
#  'stand': 592,
#  'alone': 17,
#  'complex': 82,
#  'ghost in': 151,
#  'the shell': 642,
#  'shell stand': 554,
#  'stand alone': 593,
#  'alone complex': 18,
#  'ghost in the': 152,
#  'in the shell': 222,
#  'the shell stand': 643,
#  'shell stand alone': 555,
#  'stand alone complex': 594,
#  'kuroshitsuji': 295,
#  'book': 57,
#  'of': 448,
#  'book of': 58,
#  'of the': 451,
#  'kamisama': 252,
#  'hajimemashita': 174,
#  'kako': 246,
#  'kamisama hajimemashita': 253,
#  'kako hen': 247,
#  'kuroko': 292,
#  'basket': 38,
#  'kuroko no': 293,
#  'no basket': 400,
#  'kuroko no basket': 294,
#  'major': 337,
#  'piece': 481,
#  'one piece': 454,
#  'on': 452,
#  'michi': 352,
#  'nichijou': 395,
#  'usagi': 665,
#  'kingdom': 275,
#  'psycho': 487,
#  'ko': 280,
#  'game': 140,
#  'kuni': 291,
#  'no kuni': 414,
#  'shingeki': 558,
#  'kyojin': 296,
#  'shingeki no': 559,
#  'no kyojin': 415,
#  'shingeki no kyojin': 560,
#  'specials': 590,
#  'detective': 97,
#  'conan': 83,
#  'episode': 117,
#  'detective conan': 98,
#  'mahou': 333,
#  'shoujo': 569,
#  'madoka': 325,
#  'magica': 330,
#  'mahou shoujo': 334,
#  'shoujo madoka': 570,
#  'madoka magica': 326,
#  'magica movie': 331,
#  'no monogatari': 420,
#  'mahou shoujo madoka': 335,
#  'shoujo madoka magica': 571,
#  'madoka magica movie': 327,
#  'senkan': 543,
#  'yamato': 693,
#  'uchuu senkan': 660,
#  'senkan yamato': 544,
#  'uchuu senkan yamato': 661,
#  'world': 681,
#  'world series': 682,
#  'evangelion': 119,
#  'you': 696,
#  'tonari': 655,
#  'tonari no': 656,
#  'kino': 276,
#  'tabi': 616,
#  'beautiful': 43,
#  'kino no': 277,
#  'no tabi': 430,
#  'tabi the': 617,
#  'the beautiful': 634,
#  'beautiful world': 44,
#  'kino no tabi': 278,
#  'no tabi the': 431,
#  'tabi the beautiful': 618,
#  'the beautiful world': 635,
#  'magi': 328,
#  'magic': 329,
#  're': 493,
#  'stay': 596,
#  'night': 396,
#  'heaven': 186,
#  'fate stay': 124,
#  'stay night': 597,
#  'fate stay night': 125,
#  'koushinryou': 289,
#  'ookami to': 460,
#  'to koushinryou': 647,
#  'ookami to koushinryou': 461,
#  'ace': 10,
#  'girls': 158,
#  'panzer': 474,
#  'noragami': 444,
#  'phantom': 480,
#  'conan movie': 84,
#  'detective conan movie': 99,
#  'unlimited': 662,
#  'blade': 51,
#  'works': 680,
#  'night unlimited': 397,
#  'unlimited blade': 663,
#  'blade works': 52,
#  'stay night unlimited': 598,
#  'night unlimited blade': 398,
#  'unlimited blade works': 664,
#  'ni': 392,
#  'nodame': 435,
#  'cantabile': 65,
#  'nodame cantabile': 436,
#  'mukou': 370,
#  'tsubasa': 657,
#  'tokyo': 654,
#  'ova': 471,
#  'kono': 285,
#  'sekai': 537,
#  'nanatsu': 381,
#  'nanatsu no': 382,
#  'island': 228,
#  'final': 127,
#  'road': 496,
#  'yuru': 701,
#  'subarashii': 604,
#  'shukufuku': 577,
#  'kono subarashii': 286,
#  'subarashii sekai': 605,
#  'sekai ni': 538,
#  'ni shukufuku': 393,
#  'shukufuku wo': 578,
#  'kono subarashii sekai': 287,
#  'subarashii sekai ni': 606,
#  'sekai ni shukufuku': 539,
#  'ni shukufuku wo': 394,
#  'toki': 653,
#  'kai': 245,
#  'gin': 153,
#  'hachimitsu': 164,
#  'clover': 75,
#  'hachimitsu to': 165,
#  'to clover': 646,
#  'hachimitsu to clover': 166,
#  'film': 126,
#  'piece film': 484,
#  'one piece film': 456,
#  'kanojo': 259,
#  'bungou': 62,
#  'stray': 602,
#  'dogs': 103,
#  'bungou stray': 63,
#  'stray dogs': 603,
#  'bungou stray dogs': 64,
#  'inuyasha': 226,
#  'little': 308,
#  'dragon': 105,
#  'ball': 36,
#  'dragon ball': 106,
#  'initial': 223,
#  'stage': 591,
#  'kanata': 254,
#  'll': 312,
#  'be': 41,
#  'here': 188,
#  'mirai': 353,
#  'kyoukai no': 302,
#  'no kanata': 409,
#  'kanata movie': 255,
#  'movie ll': 365,
#  'll be': 313,
#  'be here': 42,
#  'kyoukai no kanata': 303,
#  'no kanata movie': 410,
#  'kanata movie ll': 256,
#  'movie ll be': 366,
#  'll be here': 314,
#  'mobile': 356,
#  'suit': 607,
#  'gundam': 160,
#  'mobile suit': 357,
#  'suit gundam': 608,
#  'mobile suit gundam': 358,
#  'xxxholic': 686,
#  'durarara': 107,
#  'last': 305,
#  'basket movie': 39,
#  'no basket movie': 401,
#  'cardcaptor': 67,
#  'sakura': 510,
#  'card': 66,
#  'cardcaptor sakura': 68,
#  'saint': 505,
#  'seiya': 533,
#  'lost': 315,
#  'meiou': 347,
#  'saint seiya': 506,
#  'seiya the': 536,
#  'the lost': 639,
#  'saint seiya the': 508,
#  'working': 679,
#  'yahari': 687,
#  'ore': 463,
#  'seishun': 528,
#  'love': 316,
#  'comedy': 79,
#  'machigatteiru': 323,
#  'yahari ore': 688,
#  'ore no': 464,
#  'no seishun': 424,
#  'seishun love': 529,
#  'love comedy': 317,
#  'comedy wa': 80,
#  'wa machigatteiru': 670,
#  'yahari ore no': 689,
#  'ore no seishun': 465,
#  'no seishun love': 425,
#  'seishun love comedy': 530,
#  'love comedy wa': 318,
#  'comedy wa machigatteiru': 81,
#  'first': 128,
#  'mou': 361,
#  'hitori': 199,
#  'nakama': 376,
#  'piece episode': 482,
#  'episode of': 118,
#  'hitori no': 200,
#  'nakama no': 377,
#  'one piece episode': 455,
#  'piece episode of': 483,
#  'space': 587,
#  'black': 49,
#  'the second': 641,
#  'sky': 581,
#  'desu': 95,
#  'hoshi': 206,
#  'sekaiichi': 540,
#  'hatsukoi': 185,
#  'sekaiichi hatsukoi': 541,
#  'yowamushi': 697,
#  'pedal': 476,
#  'yowamushi pedal': 698,
#  'non': 440,
#  'biyori': 48,
#  'non non': 442,
#  'non biyori': 441,
#  'non non biyori': 443,
#  'kizuna': 279,
#  'no kizuna': 413,
#  'summer': 611,
#  'metal': 350,
#  'kami': 249,
#  'nomi': 437,
#  'zo': 721,
#  'shiru': 566,
#  'kami nomi': 250,
#  'nomi zo': 438,
#  'zo shiru': 722,
#  'shiru sekai': 567,
#  'kami nomi zo': 251,
#  'nomi zo shiru': 439,
#  'zo shiru sekai': 723,
#  '10': 2,
#  'requiem': 495,
#  'another': 22,
#  'maid': 336,
#  'sama': 511,
#  '00': 0,
#  'gundam 00': 161,
#  'suit gundam 00': 609,
#  'princess': 486,
#  'hades': 167,
#  'seiya meiou': 534,
#  'meiou hades': 348,
#  'saint seiya meiou': 507,
#  'seiya meiou hades': 535,
#  'x2': 683,
#  'durarara x2': 108,
#  'jikan': 235,
#  'no jikan': 408,
#  'chi': 70,
#  'lupin': 321,
#  'lupin iii': 322,
#  'ie': 215,
#  'yuri': 700,
#  'yuuki': 704,
#  'yuuna': 707,
#  'yuusha': 710,
#  'de': 90,
#  'aru': 30,
#  'yakusoku': 691,
#  'yuuki yuuna': 705,
#  'yuuna wa': 708,
#  'wa yuusha': 671,
#  'yuusha de': 711,
#  'de aru': 91,
#  'no shou': 429,
#  'yuuki yuuna wa': 706,
#  'yuuna wa yuusha': 709,
#  'wa yuusha de': 672,
#  'yuusha de aru': 712,
#  'kokoro': 284,
#  'ou': 466,
#  'gaogaigar': 141,
#  'yuusha ou': 713,
#  'ou gaogaigar': 467,
#  'yuusha ou gaogaigar': 714,
#  'naruto': 383,
#  'full': 131,
#  'panic': 473,
#  'full metal': 132,
#  'metal panic': 351,
#  'full metal panic': 133,
#  'the last': 638,
#  'kun': 290,
#  'junjou': 242,
#  'romantica': 498,
#  'junjou romantica': 243,
#  'tamayura': 623,
#  'sotsugyou': 583,
#  'shashin': 551,
#  'part': 475,
#  'tamayura sotsugyou': 624,
#  'sotsugyou shashin': 584,
#  'shashin part': 552,
#  'tamayura sotsugyou shashin': 625,
#  'sotsugyou shashin part': 585,
#  'suru': 613,
#  'witch': 676,
#  'little witch': 309,
#  'witch academia': 677,
#  'little witch academia': 310,
#  'taikai': 620,
#  'taikai hen': 621,
#  'persona': 477,
#  'winter': 674,
#  'persona the': 478,
#  'the movie': 640,
#  'movie winter': 368,
#  'persona the movie': 479,
#  'senki': 545,
#  'akagami': 13,
#  'shirayuki': 563,
#  'akagami no': 14,
#  'no shirayuki': 427,
#  'shirayuki hime': 564,
#  'akagami no shirayuki': 15,
#  'no shirayuki hime': 428,
#  'fairy': 121,
#  'tail': 622,
#  'fairy tail': 122,
#  'free': 130,
#  'kyou': 298,
#  'kyou kara': 299,
#  'no bouken': 402,
#  'shounen': 573,
#  'doraemon': 104,
#  'to the': 651,
#  'hidamari': 193,
#  'sketch': 580,
#  'hidamari sketch': 194,
#  'slayers': 582,
#  'next': 389,
#  'toaru': 652,
#  'city hunter': 73,
#  'live': 311,
#  'school': 520,
#  'love live': 319,
#  'nurarihyon': 445,
#  'mago': 332,
#  'nurarihyon no': 446,
#  'no mago': 419,
#  'nurarihyon no mago': 447,
#  'for': 129,
#  'rumble': 499,
#  'school rumble': 521,
#  'tennis': 626,
#  'ouji': 468,
#  'zenkoku': 715,
#  'tennis no': 627,
#  'no ouji': 421,
#  'ouji sama': 469,
#  'sama zenkoku': 514,
#  'zenkoku taikai': 716,
#  'tennis no ouji': 628,
#  'no ouji sama': 422,
#  'ouji sama zenkoku': 470,
#  'sama zenkoku taikai': 515,
#  'zenkoku taikai hen': 717,
#  'senshi': 547,
#  'tachi': 619,
#  'children': 71,
#  'sengoku': 542,
#  'gaiden': 138,
#  'to boku': 645,
#  'memories': 349,
#  'star': 595,
#  'cup': 85,
#  'overlord': 472,
#  '09': 1,
#  '21': 3,
#  'moon': 360,
#  'days': 89,
#  'macross': 324,
#  'luffy': 320,
#  'naki': 378,
#  'ie naki': 216,
#  'naki ko': 379,
#  'ie naki ko': 217,
#  'jigoku': 233,
#  'jigoku shoujo': 234,
#  'yume': 699,
#  'haikyuu movie': 170,
#  'sayonara': 517,
#  'no tsubasa': 432,
#  'itsumo': 229,
#  'wa itsumo': 668,
#  'saiyuuki': 509,
#  'hai': 168,
#  'yuru yuri': 702,
#  'koi': 282,
#  'yakusoku no': 692,
#  'bishoujo': 45,
#  'sailor': 503,
#  'bishoujo senshi': 46,
#  'senshi sailor': 548,
#  'sailor moon': 504,
#  'bishoujo senshi sailor': 47,
#  'senshi sailor moon': 549,
#  'zetsubou': 719,
#  'sensei': 546,
#  'sayonara zetsubou': 518,
#  'zetsubou sensei': 720,
#  'sayonara zetsubou sensei': 519,
#  'digimon': 101,
#  'adventure': 11,
#  'digimon adventure': 102,
#  'maou': 339,
#  'legend': 306,
#  'hakuouki': 175,
#  'home': 201,
#  'sweet': 614,
#  'sweet home': 615,
#  'higashi': 195,
#  'eden': 109,
#  'higashi no': 196,
#  'no eden': 403,
#  'higashi no eden': 197,
#  'maria': 340,
#  'miteru': 354,
#  'maria sama': 341,
#  'sama ga': 512,
#  'ga miteru': 137,
#  'maria sama ga': 342,
#  'sama ga miteru': 513,
#  'seitokai': 531,
#  'yakuindomo': 690,
#  'seitokai yakuindomo': 532,
#  'break': 60,
#  'break blade': 61,
#  'ka': 244,
#  'desu ka': 96,
#  'hoozuki': 203,
#  'reitetsu': 494,
#  'hoozuki no': 204,
#  'no reitetsu': 423,
#  'hoozuki no reitetsu': 205,
#  'movie 09': 363,
#  'jungle': 239,
#  'hare': 181,
#  'nochi': 433,
#  'guu': 163,
#  'jungle wa': 240,
#  'itsumo hare': 230,
#  'hare nochi': 182,
#  'nochi guu': 434,
#  'jungle wa itsumo': 241,
#  'wa itsumo hare': 669,
#  'itsumo hare nochi': 231,
#  'hare nochi guu': 183,
#  'movie the': 367,
#  'seikai': 525,
#  'seikai no': 526,
#  'no senki': 426,
#  'seikai no senki': 527,
#  'ajin': 12,
#  'baka': 32,
#  'test': 629,
#  'shoukanjuu': 572,
#  'baka to': 33,
#  'to test': 649,
#  'test to': 630,
#  'to shoukanjuu': 648,
#  'baka to test': 34,
#  'to test to': 650,
#  'test to shoukanjuu': 631,
#  'ng': 390,
#  'shuu': 579,
#  'ng shuu': 391,
#  'wing': 673,
#  'gundam wing': 162,
#  'suit gundam wing': 610,
#  'new initial': 387,
#  'initial movie': 224,
#  'movie legend': 364,
#  'new initial movie': 388,
#  'initial movie legend': 225,
#  'edition': 110,
#  'special edition': 589,
#  'kakusei': 248,
#  'shin': 557,
#  'koi wa': 283,
#  'danganronpa': 86,
#  'end': 114,
#  'kibougamine': 268,
#  'danganronpa the': 87,
#  'the end': 636,
#  'end of': 115,
#  'of kibougamine': 449,
#  'kibougamine gakuen': 269,
#  'danganronpa the end': 88,
#  'the end of': 637,
#  'end of kibougamine': 116,
#  'of kibougamine gakuen': 450,
#  'precure': 485,
#  'hetalia': 191,
#  '365': 6,
#  'ao': 25,
#  'exorcist': 120,
#  'ao no': 26,
#  'no exorcist': 404,
#  'ao no exorcist': 27,
#  'jack': 232,
#  'black jack': 50,
#  'bokura': 56,
#  'sou': 586,
#  'dead': 92,
#  'ranma': 492,
#  'haru': 184,
#  'genshiken': 149,
#  'winter cup': 675,
#  'basket movie winter': 40,
#  'movie winter cup': 369,
#  'chan': 69,
#  'hourou': 207,
#  'ichigo': 213,
#  'mashimaro': 343,
#  'ichigo mashimaro': 214,
#  'super': 612,
#  'orange': 462,
#  'kyojin movie': 297,
#  'no kyojin movie': 416,
#  'huyao': 210,
#  'xiao': 684,
#  'hongniang': 202,
#  'huyao xiao': 211,
#  'xiao hongniang': 685,
#  'huyao xiao hongniang': 212}

# %% [markdown]
# Повтороное создание матриц и словарей, но с символами в качестве параметров

# %%
vectorizer_title_ch = TfidfVectorizer(analyzer='char')

vX_train_title_ch = vectorizer_title_ch.fit(X_train['Title'])
print('vX_train_title_ch.vocabulary: ', len(vX_train_title_ch.vocabulary_))
vX_valid_title_ch = vectorizer_title_ch.fit(X_valid['Title'])
print('vX_valid_title_ch.vocabulary_: ', len(vX_valid_title_ch.vocabulary_))
vX_test_title_ch = vectorizer_title_ch.fit(X_test['Title'])
print('vX_test_title_ch.vocabulary_: ', len(vX_test_title_ch.vocabulary_))

X_train_title_ch = vectorizer_title_ch.transform(X_train['Title'])
print('X_train_title_ch.shape: ', X_train_title_ch.shape)
X_valid_title_ch = vectorizer_title_ch.transform(X_valid['Title'])
print('X_valid_title_ch.shape: ', X_valid_title_ch.shape)
X_test_title_ch = vectorizer_title_ch.transform(X_test['Title'])
print('X_test_title_ch.shape: ', X_test_title_ch.shape)
# Out:
# vX_train_title_ch.vocabulary:  68
# vX_valid_title_ch.vocabulary_:  59
# vX_test_title_ch.vocabulary_:  34
# X_train_title_ch.shape:  (1094, 34)
# X_valid_title_ch.shape:  (469, 34)
# X_test_title_ch.shape:  (10, 34)

# %% [markdown]
# Создание матриц с помощью DictVectorizer, для пропущенных значений <i>(например, title или любой другой категоральный признак)</i>

# %%
from sklearn.feature_extraction import DictVectorizer
vectorizer_feats = DictVectorizer()

tmp_dict_train = X_train[feats].fillna('-').T.to_dict().values()
tmp_dict_valid = X_valid[feats].fillna('-').T.to_dict().values()
tmp_dict_test = X_test[feats].fillna('-').T.to_dict().values()

X_train_feats = vectorizer_feats.fit_transform(tmp_dict_train)
X_valid_feats = vectorizer_feats.transform(tmp_dict_valid)
X_test_feats = vectorizer_feats.transform(tmp_dict_test)
print(X_train_feats.shape)

print(X_valid_feats.shape)

print(X_test_feats.shape)
# Out:
# (1094, 1358)
# (469, 1358)
# (10, 1358)

# %% [markdown]
# Объединение полученных матриц

# %%
X_train_new = scipy.sparse.hstack([X_train_title, X_train_feats, X_train_title_ch])

X_valid_new = scipy.sparse.hstack([X_valid_title, X_valid_feats, X_valid_title_ch])

X_test_new = scipy.sparse.hstack([X_test_title, X_test_feats, X_test_title_ch])

print(X_train_new.shape)

print(X_valid_new.shape)

print(X_test_new.shape)
# Out:
# (1094, 2118)
# (469, 2118)
# (10, 2118)

# %%
# %%time
model_1 = Ridge(alpha=.1, random_state=1)
model_1.fit(X_train_new, y_train)

train_preds1 = model_1.predict(X_train_new)
valid_preds1 = model_1.predict(X_valid_new)

print('Ощибка на трейне:', mean_squared_error(y_train, train_preds1))
print('Ошибка на тесте:', mean_squared_error(y_valid, valid_preds1))
# Out:
# Ощибка на трейне: 0.00029015941384328
# Ошибка на тесте: 0.1683354598486195
# Wall time: 45 ms

# %%
# %%time
model_2 = Ridge(alpha=1.8, random_state=1)
model_2.fit(X_train_new, y_train)

train_preds2 = model_2.predict(X_train_new)
valid_preds2 = model_2.predict(X_valid_new)

print('Ощибка на трейне:', mean_squared_error(y_train, train_preds2))
print('Ошибка на тесте:', mean_squared_error(y_valid, valid_preds2))
# Out:
# Ощибка на трейне: 0.01809254317436949
# Ошибка на тесте: 0.17346026741416473
# Wall time: 23 ms

# %% [markdown]
# # Вывод:
# Результаты показывают, что model_1 показывает лучшие результаты по сравнению с model_2, так как достигает более низких значений cреднеквадратичной ошибки MSE как на обучающем, так и на валидационном наборе данных. Кроме того, model_1 требует больше времени на обучение по сравнению с model_2.
